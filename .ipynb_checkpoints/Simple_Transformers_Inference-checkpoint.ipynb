# %% [markdown]
# <a href="https://colab.research.google.com/github/kitsamho/imdb_app/blob/main/Simple_Transformers_Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install transformers==3.0.2

# %%
# !pip install simpletransformers
# Out:
# ...
#      |████████████████████████████████| 221 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 264 kB 12.2 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.5 MB/s
# ...
#      |████████████████████████████████| 124 kB 13.5 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 12.6 MB/s
# ...
#      |████████████████████████████████| 2.6 MB 36.7 MB/s
# ...
#      |████████████████████████████████| 76 kB 6.6 MB/s
# ...
#      |████████████████████████████████| 7.9 MB 25.9 MB/s
# ...
#      |████████████████████████████████| 636 kB 55.5 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 62.2 MB/s
# ...
#      |████████████████████████████████| 133 kB 71.5 MB/s
# ...
#      |████████████████████████████████| 188 kB 70.0 MB/s
# ...
#      |████████████████████████████████| 170 kB 74.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 118 kB 56.3 MB/s
# ...
#      |████████████████████████████████| 243 kB 60.7 MB/s
# ...
#      |████████████████████████████████| 75 kB 5.5 MB/s
# ...

# %%
# Importing stock ml libraries
import warnings
warnings.simplefilter('ignore')
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn import metrics
import transformers
import torch
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import DistilBertTokenizer, DistilBertModel
import logging
logging.basicConfig(level=logging.ERROR)
# Out:
# 2021-08-01 19:27:46.826331: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_json('/content/drive/MyDrive/tmdb_data_main.json')

# %%
df = df[['tmdb_id','movie','overview','genres','genres_new','popularity','release_year','vote_average','budget','revenue','poster_path']]
df = df.dropna(subset=['genres'])
genre_include = df.explode('genres').genres.value_counts().keys()[0:12]

def genres_check(film_genres):
    
    for genre in film_genres:
        if genre not in genre_include:
            return False
    return True

def multi_label_prep(film_genres):
    prep = []
    for genre in genre_include:
        if genre in film_genres:
            prep.append(1)
        else:
            prep.append(0)
            
    return prep

df['genres_valid'] = df['genres'].apply(genres_check)
df = df[df.genres_valid ==True]
df.shape
genre_include = list(genre_include)
genre_include.sort()
genre_include



df['labels'] = df['genres'].apply(multi_label_prep)

# %%
df = pd.concat([df[['overview']],df[['labels']]['labels'].apply(pd.Series)],axis=1)

# %%
df.columns = ['overview']+genre_include
df
# Out:
#                                                 overview  ...  Thriller
# 0      Jack Torrance accepts a caretaker job at the O...  ...         1
# 2      Spanning the years 1945 to 1955, a chronicle o...  ...         0
# 4      In a near-future Britain, young Alexander DeLa...  ...         0
# 5      Camp counselors are stalked and murdered by an...  ...         0
# 6      A Coca-Cola bottle dropped from an airplane ra...  ...         0
# ...                                                  ...  ...       ...
# 19615  The story of Ba Sang – the second of the 4 noi...  ...         0
# 19622  Drill-bit is a drilling prodigy who is offered...  ...         0
# 19638  Bob Spit, a comic book character, lives in a p...  ...         0
# 19639  Following the end of the acclaimed tv series, ...  ...         0
# 19658  A trimmed edit of Peter Jackson's The Hobbit t...  ...         0
#
# [15001 rows x 13 columns]

# %%
df['labels'] = list(zip(df.Action.tolist(), df.Adventure.tolist(), df.Animation.tolist(), 
                        df.Comedy.tolist(),  df.Crime.tolist(), df.Drama.tolist(),
                        df.Family.tolist(),  df.Fantasy.tolist(), df.Horror.tolist(),
                        df.Romance.tolist(),  df['Science Fiction'].tolist(), df.Thriller.tolist(),
                        
                        ))
df['text'] = df['overview']

# %%
from sklearn.model_selection import train_test_split


train_df, eval_df = train_test_split(df, test_size=0.2)

# %%
train_df[['labels','text']]
# Out:
#                                                 overview  ...                                               text
# 115    After losing their academic posts at a prestig...  ...  After losing their academic posts at a prestig...
# 15161  Turtles can fly tells the story of a group of ...  ...  Turtles can fly tells the story of a group of ...
# 15844  If Nick Barrow can stay alive for 21 days, he'...  ...  If Nick Barrow can stay alive for 21 days, he'...
# 366    Joan Wilder is thrust back into a world of mur...  ...  Joan Wilder is thrust back into a world of mur...
# 3893   Nothing gets between Anne Marie and her board....  ...  Nothing gets between Anne Marie and her board....
# ...                                                  ...  ...                                                ...
# 5399   Bree is about to get a sex reassignment surger...  ...  Bree is about to get a sex reassignment surger...
# ...

# %%
from simpletransformers.classification import MultiLabelClassificationModel, ClassificationModel

# %%
simpletransformers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_183/3079804675.py in <module>
# ----> 1 simpletransformers
#
# NameError: name 'simpletransformers' is not defined

# %%
import torch


cuda_available = torch.cuda.is_available()

# %%
cuda_available
# Out:
# True

# %%
model = MultiLabelClassificationModel('distilbert', 'distilbert-base-uncased', num_labels=12, args={'train_batch_size':2, 'gradient_accumulation_steps':16, 'learning_rate': 3e-5, 'num_train_epochs': 5, 'max_seq_length': 512},use_cuda=True)
# Out:
#   File "/tmp/ipykernel_183/3951490326.py", line 1
#     model = MultiLabelClassificationModel('distilbert', 'distilbert-base-uncased', num_labels=12, args={'train_batch_size':2, 'gradient_accumulation_steps':16, 'learning_rate': 3e-5, 'num_train_epochs': 5, 'max_seq_length': 512},use_cuda=True,overwrite_output_dir:True)
#                                                                                                                                                                                                                                                                        ^
# SyntaxError: invalid syntax

# %%
model.train_model(train_df[['labels','text']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_183/1538569723.py in <module>
# ----> 1 model.train_model(train_df[['labels','text']])
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/multi_label_classification_model.py in train_model(self, train_df, multi_label, eval_df, output_dir, show_running_loss, args, verbose, **kwargs)
#     300             verbose=True,
#     301             args=args,
# --> 302             **kwargs,
#     303         )
#     304
#
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py in train_model(self, train_df, multi_label, output_dir, show_running_loss, args, eval_df, verbose, **kwargs)
#     551                 "Output directory ({}) already exists and is not empty."
# ...

# %%
result, model_outputs, wrong_predictions = model.eval_model(eval_df)
# Out:
# ...
# Running Evaluation:   0%|          | 0/376 [00:00<?, ?it/s]

# %%
result
# Out:
# {'LRAP': 0.7768080039194427, 'eval_loss': 0.3222861051004618}

# %%
test = ['During the WWII, acclaimed Polish musician Wladyslaw faces various struggles as he loses contact with his family. As the situation worsens, he hides in the ruins of Warsaw in order to survive.']

# %%
# to_predict = test_df.comment_text.apply(lambda x: x.replace('\n', ' ')).tolist()
preds, outputs = model.predict(test)

sub_df = pd.DataFrame(outputs, columns=genre_include)


# sub_df['id'] = test_df['id']
# sub_df = sub_df[['id', 'toxic','severe_toxic','obscene','threat','insult','identity_hate']]
# Out:
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
sub_df
# Out:
#      Action  Adventure  Animation  ...   Romance  Science Fiction  Thriller
# 0  0.105408    0.05899    0.04361  ...  0.124939         0.074768  0.227783
#
# [1 rows x 12 columns]
